# %%
# coding: utf-8
from bs4 import BeautifulSoup
import os
import re
import requests
import pandas as pd
import time

#class MercariScraping:
    """
    mercariから品目、配送元、出品者、写真、最新20件の口コミを取得する

# %%
# coding: utf-8

import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import time

class Tabelog:
    """
    食べログスクレイピングクラス
    test_mode=Trueで動作させると、最初のページの３店舗のデータのみを取得できる
    """
    def __init__(self, base_url, test_mode=False, p_ward='東京都内', begin_page=1, end_page=30):

        # 変数宣言
        self.store_id = ''
        self.store_id_num = 0
        self.store_name = ''
        self.score = 0
        self.ward = p_ward
        self.review_cnt = 0
        self.review = ''
        self.columns = ['store_id', 'store_name', 'score', 'ward', 'review_cnt', 'review']
        self.df = pd.DataFrame(columns=self.columns)
        self.__regexcomp = re.compile(r'\n|\s') # \nは改行、\sは空白

        page_num = begin_page # 店舗一覧ページ番号

        if test_mode:
            list_url = base_url + str(page_num) +  '/?Srt=D&SrtT=rt&sort_mode=1' #食べログの点数ランキングでソートする際に必要な処理
            self.scrape_list(list_url, mode=test_mode)
        else:
            while True:
                list_url = base_url + str(page_num) +  '/?Srt=D&SrtT=rt&sort_mode=1' #食べログの点数ランキングでソートする際に必要な処理
                if self.scrape_list(list_url, mode=test_mode) != True:
                    break

                # INパラメータまでのページ数データを取得する
                if page_num >= end_page:
                    break
                page_num += 1
        return

    def scrape_list(self, list_url, mode):
        """
        店舗一覧ページのパーシング
        """
        r = requests.get(list_url)
        if r.status_code != requests.codes.ok:
            return False

        soup = BeautifulSoup(r.content, 'html.parser')
        soup_a_list = soup.find_all('a', class_='list-rst__rst-name-target') # 店名一覧

        if len(soup_a_list) == 0:
            return False

        if mode:
            for soup_a in soup_a_list[:2]:
                item_url = soup_a.get('href') # 店の個別ページURLを取得
                self.store_id_num += 1
                self.scrape_item(item_url, mode)
        else:
            for soup_a in soup_a_list:
                item_url = soup_a.get('href') # 店の個別ページURLを取得
                self.store_id_num += 1
                self.scrape_item(item_url, mode)

        return True

    def scrape_item(self, item_url, mode):
        """
        個別店舗情報ページのパーシング
        """
        start = time.time()

        r = requests.get(item_url)
        if r.status_code != requests.codes.ok:
            print(f'error:not found{ item_url }')
            return

        soup = BeautifulSoup(r.content, 'html.parser')

        # 店舗名称取得
        # <h2 class="display-name">
        #     <span>
        #         麺匠　竹虎 新宿店
        #     </span>
        # </h2>
        store_name_tag = soup.find('h2', class_='display-name')
        store_name = store_name_tag.span.string
        print('{}→店名：{}'.format(self.store_id_num, store_name.strip()), end='')
        self.store_name = store_name.strip()

        # ラーメン屋、つけ麺屋以外の店舗は除外
        store_head = soup.find('div', class_='rdheader-subinfo') # 店舗情報のヘッダー枠データ取得
        store_head_list = store_head.find_all('dl')
        store_head_list = store_head_list[1].find_all('span')
        #print('ターゲット：', store_head_list[0].text)

        if store_head_list[0].text not in {'ラーメン', 'つけ麺'}:
            print('ラーメンorつけ麺のお店ではないので処理対象外')
            self.store_id_num -= 1
            return

        # 評価点数取得
        #<b class="c-rating__val rdheader-rating__score-val" rel="v:rating">
        #    <span class="rdheader-rating__score-val-dtl">3.58</span>
        #</b>
        rating_score_tag = soup.find('b', class_='c-rating__val')
        rating_score = rating_score_tag.span.string
        print('  評価点数：{}点'.format(rating_score), end='')
        self.score = rating_score

        # 評価点数が存在しない店舗は除外
        if rating_score == '-':
            print('  評価がないため処理対象外')
            self.store_id_num -= 1
            return
       # 評価が3.5未満店舗は除外
        if float(rating_score) < 3.5:
            print('  食べログ評価が3.5未満のため処理対象外')
            self.store_id_num -= 1
            return

        # レビュー一覧URL取得
        #<a class="mainnavi" href="https://tabelog.com/tokyo/A1304/A130401/13143442/dtlrvwlst/"><span>口コミ</span><span class="rstdtl-navi__total-count"><em>60</em></span></a>
        review_tag_id = soup.find('li', id="rdnavi-review")
        review_tag = review_tag_id.a.get('href')

        # レビュー件数取得
        print('  レビュー件数：{}'.format(review_tag_id.find('span', class_='rstdtl-navi__total-count').em.string), end='')
        self.review_cnt = review_tag_id.find('span', class_='rstdtl-navi__total-count').em.string

        # レビュー一覧ページ番号
        page_num = 1 #1ページ*20 = 20レビュー 。この数字を変えて取得するレビュー数を調整。

        # レビュー一覧ページから個別レビューページを読み込み、パーシング
        # 店舗の全レビューを取得すると、食べログの評価ごとにデータ件数の濃淡が発生してしまうため、
        # 取得するレビュー数は１ページ分としている（件数としては１ページ*20=２0レビュー）
        while True:
            review_url = review_tag + 'COND-0/smp1/?lc=0&rvw_part=all&PG=' + str(page_num)
            #print('\t口コミ一覧リンク：{}'.format(review_url))
            print(' . ' , end='') #LOG
            if self.scrape_review(review_url) != True:
                break
            if page_num >= 1:
                break
            page_num += 1

        process_time = time.time() - start
        print('  取得時間：{}'.format(process_time))

        return

    def scrape_review(self, review_url):
        """
        レビュー一覧ページのパーシング
        """
        r = requests.get(review_url)
        if r.status_code != requests.codes.ok:
            print(f'error:not found{ review_url }')
            return False

        # 各個人の口コミページ詳細へのリンクを取得する
        #<div class="rvw-item js-rvw-item-clickable-area" data-detail-url="/tokyo/A1304/A130401/13141542/dtlrvwlst/B408082636/?use_type=0&amp;smp=1">
        #</div>
        soup = BeautifulSoup(r.content, 'html.parser')
        review_url_list = soup.find_all('div', class_='rvw-item') # 口コミ詳細ページURL一覧

        if len(review_url_list) == 0:
            return False

        for url in review_url_list:
            review_detail_url = 'https://tabelog.com' + url.get('data-detail-url')
            #print('\t口コミURL：', review_detail_url)

            # 口コミのテキストを取得
            self.get_review_text(review_detail_url)

        return True

    def get_review_text(self, review_detail_url):
        """
        口コミ詳細ページをパーシング
        """
        r = requests.get(review_detail_url)
        if r.status_code != requests.codes.ok:
            print(f'error:not found{ review_detail_url }')
            return

        # ２回以上来訪してコメントしているユーザは最新の1件のみを採用
        #<div class="rvw-item__rvw-comment" property="v:description">
        #  <p>
        #    <br>すごい煮干しラーメン凪 新宿ゴールデン街本館<br>スーパーゴールデン1600円（20食限定）を喰らう<br>大盛り無料です<br>スーパーゴールデンは、新宿ゴールデン街にちなんで、ココ本店だけの特別メニューだそうです<br>相方と歌舞伎町のtohoシネマズの映画館でドラゴンボール超ブロリー を観てきた<br>ブロリー 強すぎるね(^^)面白かったです<br>凪の煮干しラーメンも激ウマ<br>いったん麺ちゅるちゅる感に、レアチャーと大トロチャーシューのトロけ具合もうめえ<br>煮干しスープもさすが！と言うほど完成度が高い<br>さすが食べログラーメン百名店<br>と言うか<br>2日連チャンで、近場の食べログラーメン百名店のうちの2店舗、昨日の中華そば葉山さんと今日の凪<br>静岡では考えられん笑笑<br>ごちそうさまでした
        #  </p>
        #</div>
        soup = BeautifulSoup(r.content, 'html.parser')
        review = soup.find_all('div', class_='rvw-item__rvw-comment')#reviewが含まれているタグの中身をすべて取得
        if len(review) == 0:
            review = ''
        else:
            review = review[0].p.text.strip() # strip()は改行コードを除外する関数

        #print('\t\t口コミテキスト：', review)
        self.review = review

        # データフレームの生成
        self.make_df()
        return

    def make_df(self):
        self.store_id = str(self.store_id_num).zfill(8) #0パディング
        se = pd.Series([self.store_id, self.store_name, self.score, self.ward, self.review_cnt, self.review], self.columns) # 行を作成
        self.df = self.df.append(se, self.columns) # データフレームに行を追加
        return
    
    
tokyo_ramen_review = Tabelog(base_url="https://tabelog.com/tokyo/rstLst/ramen/",test_mode=True, p_ward='東京都内')
#CSV保存
tokyo_ramen_review.df.to_csv("/Users/minej/anaconda3/minejis/tokyo_ramen_review.csv")
# Out:
# 1→店名：手打式超多加水麺 ののくら  評価点数：4.09点  レビュー件数：394 .   取得時間：19.810783863067627
# 2→店名：Homemade Ramen 麦苗  評価点数：4.06点  レビュー件数：695 .   取得時間：26.785873413085938

# %%
tokyo_ramen_review = pd.read_csv('/Users/minej/anaconda3/minejis/tokyo_ramen_review.csv')
tokyo_ramen_review
# Out:
#     Unnamed: 0  store_id         store_name  score  ward  review_cnt  \
# 0            0         1      手打式超多加水麺 ののくら   4.09  東京都内         394
# 1            1         1      手打式超多加水麺 ののくら   4.09  東京都内         394
# 2            2         1      手打式超多加水麺 ののくら   4.09  東京都内         394
# 3            3         1      手打式超多加水麺 ののくら   4.09  東京都内         394
# 4            4         1      手打式超多加水麺 ののくら   4.09  東京都内         394
# 5            5         1      手打式超多加水麺 ののくら   4.09  東京都内         394
# 6            6         1      手打式超多加水麺 ののくら   4.09  東京都内         394
# 7            7         1      手打式超多加水麺 ののくら   4.09  東京都内         394
# 8            8         1      手打式超多加水麺 ののくら   4.09  東京都内         394
# 9            9         1      手打式超多加水麺 ののくら   4.09  東京都内         394
# 10          10         1      手打式超多加水麺 ののくら   4.09  東京都内         394
# 11          11         1      手打式超多加水麺 ののくら   4.09  東京都内         394
# 12          12         1      手打式超多加水麺 ののくら   4.09  東京都内         394
# 13          13         1      手打式超多加水麺 ののくら   4.09  東京都内         394
# 14          14         1      手打式超多加水麺 ののくら   4.09  東京都内         394
# 15          15         1      手打式超多加水麺 ののくら   4.09  東京都内         394
# 16          16         1      手打式超多加水麺 ののくら   4.09  東京都内         394
# 17          17         1      手打式超多加水麺 ののくら   4.09  東京都内         394
# 18          18         1      手打式超多加水麺 ののくら   4.09  東京都内         394
# 19          19         1      手打式超多加水麺 ののくら   4.09  東京都内         394
# 20          20         2  Homemade Ramen 麦苗   4.06  東京都内         695
# 21          21         2  Homemade Ramen 麦苗   4.06  東京都内         695
# 22          22         2  Homemade Ramen 麦苗   4.06  東京都内         695
# 23          23         2  Homemade Ramen 麦苗   4.06  東京都内         695
# 24          24         2  Homemade Ramen 麦苗   4.06  東京都内         695
# 25          25         2  Homemade Ramen 麦苗   4.06  東京都内         695
# 26          26         2  Homemade Ramen 麦苗   4.06  東京都内         695
# 27          27         2  Homemade Ramen 麦苗   4.06  東京都内         695
# 28          28         2  Homemade Ramen 麦苗   4.06  東京都内         695
# 29          29         2  Homemade Ramen 麦苗   4.06  東京都内         695
# 30          30         2  Homemade Ramen 麦苗   4.06  東京都内         695
# 31          31         2  Homemade Ramen 麦苗   4.06  東京都内         695
# 32          32         2  Homemade Ramen 麦苗   4.06  東京都内         695
# 33          33         2  Homemade Ramen 麦苗   4.06  東京都内         695
# 34          34         2  Homemade Ramen 麦苗   4.06  東京都内         695
# 35          35         2  Homemade Ramen 麦苗   4.06  東京都内         695
# 36          36         2  Homemade Ramen 麦苗   4.06  東京都内         695
# 37          37         2  Homemade Ramen 麦苗   4.06  東京都内         695
# 38          38         2  Homemade Ramen 麦苗   4.06  東京都内         695
# 39          39         2  Homemade Ramen 麦苗   4.06  東京都内         695
#
#                                                review
# 0   午後半休して並びました。亀有駅南口からロータリーを抜けて、バス通りをまっすぐ進んで行くと、右...
# 1   Instagram    pateknautilus40https://www.instag...
# 2   とある土曜日、妻子が妻の実家に帰るということで、この絶好の機会を活用して一食入魂！前々から訪...
# 3   食べログのラーメン部門で東京No.1になった「ののくら」にやってまいりました～！（2020年...
# 4   食べログで、とても評価が高かったので、一度は食したいと思い訪問。平日の遅い時間に行けば、待ち...
# 5   ようやくののくらに。以前亀有に伺った際は行列も少なく今ほど評価も高くなく並びもなかったので道...
# 6   この日はブラっと放浪していました。お昼ご飯に、前々から気になっていた、こちらのお店へ初訪問し...
# 7   今日は2020年10月15日時点で点数が全国No.1の「ののくら」さんです。お店到着は平日の...
# 8   到着したのが平日の10:40。なんと14人待ち！これはラッキー。コロナの影響か平日が狙い目と...
# 9   2020.9.29特製中華そば(1200円)⭐︎3.6平日の火曜開店1時間半前(9時半)到着...
# 10  東京No1、全国No2のラーメン店。長い夏休みで時間がある今こそいかねばと思い立ち、台風がず...
# 11  初訪問です。亀有駅から徒歩で5分ほどの場所にあるこちら。現在食べログのラーメンで全国2位、東...
# 12  こち亀の舞台としてあまりに有名な亀有に、ラーメンジャンルでは最高峰レベルの食べログ点数を獲得...
# 13  亀有駅から徒歩5分、超有名でご存知の人も多い”ののらく”へ。平日火曜12：53到着、15人待...
# 14  特製中華そば(醤油)チャーシューご飯さすがにバチバチ美味かった。これは完全なる名店。店名にも...
# 15  2020年、ラーメン103杯目(^^)本日、朝イチで営業を済ませ、次の打ち合わせまで時間が空...
# 16  ※食べログ始める前に行ったお店の更新です。やっっっっと念願の《ののくら》さんに。近所にミシュ...
# 17  『手打式超多加水麺 ののくら』までの詳しい道順・アクセスはブログにアップしています。http...
# 18  夏季休暇ながらコロナ禍で自粛ムード、ならば普段伺えないお店に行こうと伺ったのが此方。2017...
# 19  《東京都葛飾区》JR亀有駅から徒歩約４分、食べログのラーメン東京でトップに君臨するお店『手打...
# 20  平日休みを利用して訪問。10時くらいにお店につき、ボードを見ると最短で12時の枠に空きあり。...
# 21  平日のお昼を回った午後2時ごろにお邪魔しました。昼時をすぎているにもかかわらず、外には約10...
# 22  特上 醤油　　　　　　　　　　　　　13512月5日、今日の昼食は、先月末から営業を再開した...
# 23  2020年12月5日（土）昨日は1年10ヶ月ぶりにこちらの店を訪問です。前回は友人に誘われて...
# 24  「青麦」立ち上げのお休みから2ヶ月ぶり再開「麦苗」へ朝ウェイティングで予約した時間に向かう。...
# 25  東京は大森駅エリアにあるラーメン100名店です。姉妹店の青麦の開店にともない10月頃から休店...
# 26  2020/9 lunchチョー久々にこちらに。なんと2年半ぶり。。。かき氷は食べに行っている...
# 27  2020年9月　4年ぶりにお邪魔しました。●店舗は・・・・JR大森駅と京急大森海岸駅の中間ぐ...
# 28  ここ最近、毎週のように麦苗のラーメンを食べれている、近ければ毎日でも食べたいと思うほどです。...
# 29  都内屈指の有名店！！特に意識していたわけではないのですがこちらが今年200杯目のラーメン(つ...
# 30  2020/08/03(月)5度目の訪問！現在は蜜を避けるために、事前記帳(予約)式になってい...
# 31  ディナーのオープンは18時なのですが17時からウェイティングボードが出るのでそこに名前を書い...
# 32  ラーメン100名店に選ばれた人気のお店自宅から近いけど、いつも行列なのでもう行けること無いか...
# 33  コロナで遠出するなと言われてしまったので、都内で一番行きたかった場所に行ってきました。京急線...
# 34  うどんが主食の公式ブログ　https://alwaysudon.com/tonkatsu-m...
# 35  【食べログ 2020 BRONZE】【食べログ 2019 ラーメン TOKYO 百名店】【ミ...
# 36  ご近所の食べログレビュアーさんと地元大森グルメツアーをしました♪数店舗候補をいただきましたが...
# 37  ようやくラーメン店の2020年百名店が発表されたと思ったら…あれ？行ったのに投稿されてない？...
# 38  土曜日の9時40分頃。まずノートに名前を書きに行きます。すでにお昼の部はほとんど埋まり、あと...
# 39  火曜日の12時20分に下見に来ましたら、なんと13時15分に空きがあり、すぐさまウェイティン...
