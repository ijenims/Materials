# %%
# coding: utf-8
from bs4 import BeautifulSoup
import os
import re
import requests
import pandas as pd
import time

class TabelogScraping:
    """
    食べログから店名、ジャンル、評価点、口コミ件数、最新20件の口コミを取得する
    """
    def __init__(self, max_num):
        """
        インスタンス化した時点でスクレイピングを開始する
        食べログ（検索条件：東京都、バー、ランキング順）にアクセスする
        取得するページ件数は1ページ目からmax_numページ目までとする。
        """
        # スクレイピング対象となるお店のタグ
        self.TAGS = {'バー', 'ワインバー', 'バー・お酒（その他）', 'ラウンジ', 'ダイニングバー'}
        # スクレイピング対象となる評価点の下限値
        self.LOWER_LIMIT = 3.9
        # 口コミのURLへの不足部分
        self.RVW = 'dtlrvwlst/'
        # 取得したデータ一覧の保存場所 C:\Users\minej\anaconda3\minejis
        self.RESULT_PATH = '/Users/minej/anaconda3/minejis'
        # 取得したデータ一覧名
        self.RESULT_NAME = 'data_summary.csv'
        # 取得した口コミデータフレームの列名
        self.COLUMNS = ['store_id', 'store_name', 'genre', 'rate', 'review_cnt', 'review']
        # 検索するページ上限数
        self.max_num = max_num + 1
        self.shop_id = ''
        self.id_num = 1
        self.df = pd.DataFrame(columns = self.COLUMNS)

        try:
            first_time = time.time()
            for page_num in range(1, self.max_num):
                if page_num == 1:
                    # ランキング1ページ目
                    response = self.connect_url('https://tabelog.com/tokyo/rstLst/BC01/?SrtT=rt&Srt=D&sort_mode=1')
                else:
                    # ランキング2ページ目以降
                    response = self.connect_url('https://tabelog.com/tokyo/rstLst/BC01/' + str(page_num) + '/?SrtT=rt&Srt=D&sort_mode=1')

                # HTML解析用の変数
                soup = BeautifulSoup(response.text, 'lxml')

                # 一覧ページから以下の情報を取得する
                # ジャンルの取得
                genre_info = [genre.text.rstrip() for genre in soup.find_all('div', class_='list-rst__area-genre cpy-area-genre')]
                # 評価点の取得
                rate_list = [float(rate.text) for rate in soup.find_all('span', class_='c-rating__val c-rating__val--strong list-rst__rating-val')]
                # 口コミ件数の取得
                count_list = [count.text for count in soup.find_all('em', class_='list-rst__rvw-count-num cpy-review-count')]
                # 店名の取得
                raw_data = soup.find_all('a', class_='list-rst__rst-name-target cpy-rst-name js-ranking-num')
                shop_list = [name.text for name in raw_data]
                shop_url_list = [shop_url.get('href') for shop_url in raw_data]

                for i in range(20):
                    genre_tags = set(re.split('[\\s/、]+', genre_info[i].strip())[2:])
                    # ジャンル文字列が「バー、ワインバー、バー・お酒（その他）、ラウンジ、カフェ、ダイニングバー」の部分集合の場合、
                    # かつ評価点が「3.０以上」の場合、かつ、口コミ件数が１件以上存在する場合に処理を続ける
                    if not (genre_tags.issubset(self.TAGS) and rate_list[i] >= self.LOWER_LIMIT and int(count_list[i]) > 0):
                        continue

                    start_time = time.time()
                    self.shop_id = str(self.id_num).zfill(5)

                    # お店のURLに遷移し、口コミを20件(1ページ分)取得する
                    response = self.connect_url(shop_url_list[i] + self.RVW)
                    soup = BeautifulSoup(response.text, 'lxml')
                    review_url_list = soup.find_all('div', class_='rvw-item js-rvw-item-clickable-area')

                    # 各口コミページに遷移し、最新の口コミを取得する
                    for url in review_url_list:
                        review_detail_url = 'https://tabelog.com' + url.get('data-detail-url')
                        response = self.connect_url(review_detail_url)
                        soup = BeautifulSoup(response.text, 'lxml')
                        review = soup.find_all('div', class_='rvw-item__rvw-comment')
                        review = review[0].p.text.strip()
                        # pandasのデータフレームに格納
                        self.add_df(shop_list[i], genre_info[i].strip(), rate_list[i], count_list[i], review)

                    # 1つのお店のスクレイピングが終了したら、その結果を保存する
                    self.write_result(shop_list[i], genre_info[i].strip(), rate_list[i], count_list[i])

                    process_time = time.time() - start_time
                    print('{}件目完了：　処理時間：{:.3f}秒'.format(self.id_num, process_time))

                    self.id_num += 1

        except requests.exceptions.HTTPError as e:
            print(e)
        except requests.exceptions.ConnectTimeout as e:
            print(e)
        finally:
            end_time = time.time() - first_time
            print('終了、処理時間：{:.3f}秒'.format(end_time))


    def connect_url(self, target_url):
        """
        対象のURLにアクセスする関数
        アクセスできない等のエラーが発生したら例外を投げる
        """
        # 接続確立の待機時間、応答待機時間を10秒とし、それぞれの値を超えた場合は例外が発生（ConnectTimeout）
        data = requests.get(target_url, timeout=10)
        data.encoding = data.apparent_encoding
        # アクセス過多を避けるため、2秒スリープ
        time.sleep(2)

        # レスポンスのステータスコードが正常(200番台)以外の場合は、例外を発生させる(HTTPError)
        if data.status_code == requests.codes.ok:
            return data
        else:
            data.raise_for_status()


    def write_result(self, name, genre, rate, count):
        """
        スクレイピング対象となるお店の一覧をログとして出力する関数
        """
        file_path = os.path.join(self.RESULT_PATH, self.RESULT_NAME)
        with open(file_path, mode='a', encoding='utf-8') as f:
            f.write('{}, {}, {}, 評価：{}, 口コミ：{}件\n'.format(self.shop_id, name, genre, rate, count))


    def add_df(self, name, genre, rate, count, comment):
        """
        取得した口コミデータをデータフレームに格納する関数
        """
        se = pd.Series([self.shop_id, name, genre, rate, count, comment], self.COLUMNS)
        self.df = self.df.append(se, self.COLUMNS)


if __name__ == '__main__':
    result = TabelogScraping(2)
    print(result.df)
# Out:
# 1件目完了：　処理時間：78.967秒
# 2件目完了：　処理時間：72.151秒
# 3件目完了：　処理時間：72.973秒
# 終了、処理時間：232.097秒
#    store_id store_name          genre  rate review_cnt  \
# 0     00001   サンルーカルバー  神楽坂駅 86m / バー  4.02        159
# 1     00001   サンルーカルバー  神楽坂駅 86m / バー  4.02        159
# 2     00001   サンルーカルバー  神楽坂駅 86m / バー  4.02        159
# 3     00001   サンルーカルバー  神楽坂駅 86m / バー  4.02        159
# 4     00001   サンルーカルバー  神楽坂駅 86m / バー  4.02        159
# 5     00001   サンルーカルバー  神楽坂駅 86m / バー  4.02        159
# 6     00001   サンルーカルバー  神楽坂駅 86m / バー  4.02        159
# 7     00001   サンルーカルバー  神楽坂駅 86m / バー  4.02        159
# 8     00001   サンルーカルバー  神楽坂駅 86m / バー  4.02        159
# 9     00001   サンルーカルバー  神楽坂駅 86m / バー  4.02        159
# 10    00001   サンルーカルバー  神楽坂駅 86m / バー  4.02        159
# 11    00001   サンルーカルバー  神楽坂駅 86m / バー  4.02        159
# 12    00001   サンルーカルバー  神楽坂駅 86m / バー  4.02        159
# 13    00001   サンルーカルバー  神楽坂駅 86m / バー  4.02        159
# 14    00001   サンルーカルバー  神楽坂駅 86m / バー  4.02        159
# 15    00001   サンルーカルバー  神楽坂駅 86m / バー  4.02        159
# 16    00001   サンルーカルバー  神楽坂駅 86m / バー  4.02        159
# 17    00001   サンルーカルバー  神楽坂駅 86m / バー  4.02        159
# 18    00001   サンルーカルバー  神楽坂駅 86m / バー  4.02        159
# 19    00001   サンルーカルバー  神楽坂駅 86m / バー  4.02        159
# 20    00002   MORI BAR  銀座駅 300m / バー  3.92         67
# 21    00002   MORI BAR  銀座駅 300m / バー  3.92         67
# 22    00002   MORI BAR  銀座駅 300m / バー  3.92         67
# 23    00002   MORI BAR  銀座駅 300m / バー  3.92         67
# 24    00002   MORI BAR  銀座駅 300m / バー  3.92         67
# 25    00002   MORI BAR  銀座駅 300m / バー  3.92         67
# 26    00002   MORI BAR  銀座駅 300m / バー  3.92         67
# 27    00002   MORI BAR  銀座駅 300m / バー  3.92         67
# 28    00002   MORI BAR  銀座駅 300m / バー  3.92         67
# 29    00002   MORI BAR  銀座駅 300m / バー  3.92         67
# 30    00002   MORI BAR  銀座駅 300m / バー  3.92         67
# 31    00002   MORI BAR  銀座駅 300m / バー  3.92         67
# 32    00002   MORI BAR  銀座駅 300m / バー  3.92         67
# 33    00002   MORI BAR  銀座駅 300m / バー  3.92         67
# 34    00002   MORI BAR  銀座駅 300m / バー  3.92         67
# 35    00002   MORI BAR  銀座駅 300m / バー  3.92         67
# 36    00002   MORI BAR  銀座駅 300m / バー  3.92         67
# 37    00002   MORI BAR  銀座駅 300m / バー  3.92         67
# 38    00002   MORI BAR  銀座駅 300m / バー  3.92         67
# 39    00002   MORI BAR  銀座駅 300m / バー  3.92         67
# 40    00003        石の華  渋谷駅 325m / バー  3.91        155
# 41    00003        石の華  渋谷駅 325m / バー  3.91        155
# 42    00003        石の華  渋谷駅 325m / バー  3.91        155
# 43    00003        石の華  渋谷駅 325m / バー  3.91        155
# 44    00003        石の華  渋谷駅 325m / バー  3.91        155
# 45    00003        石の華  渋谷駅 325m / バー  3.91        155
# 46    00003        石の華  渋谷駅 325m / バー  3.91        155
# 47    00003        石の華  渋谷駅 325m / バー  3.91        155
# 48    00003        石の華  渋谷駅 325m / バー  3.91        155
# 49    00003        石の華  渋谷駅 325m / バー  3.91        155
# 50    00003        石の華  渋谷駅 325m / バー  3.91        155
# 51    00003        石の華  渋谷駅 325m / バー  3.91        155
# 52    00003        石の華  渋谷駅 325m / バー  3.91        155
# 53    00003        石の華  渋谷駅 325m / バー  3.91        155
# 54    00003        石の華  渋谷駅 325m / バー  3.91        155
# 55    00003        石の華  渋谷駅 325m / バー  3.91        155
# 56    00003        石の華  渋谷駅 325m / バー  3.91        155
# 57    00003        石の華  渋谷駅 325m / バー  3.91        155
# 58    00003        石の華  渋谷駅 325m / バー  3.91        155
# 59    00003        石の華  渋谷駅 325m / バー  3.91        155
#
#                                                review
# 0   神楽坂駅の目の前、PM2:00から開いてる「Sanlucar BAR」虎白の後、神楽坂を少し...
# 1   オーセンティックバーを始めとした名店と言えるバーの多い神楽坂界隈にあって、名実ともにナンバー...
# 2   Instagram (bottan222)ーーーーーーーーーーーーー2020/09　今日は２...
# 3   twitter ID :  jigenace777Instagram ID : jigena...
# 4   2020年8月28日（金）ディジェスティフ。相方と。あげづきでとんかつを食べたあと、せっかく...
# 5   うどんが主食の公式ブログ　https://alwaysudon.com/kawada-nin...
# 6   【食べログ 全国×バー 第1位】(投稿時)【食べログ 2020 TOP 500】現在 Bar...
# 7   1月の「サンルーカルバー」に伺いました。今回も何杯か頂いたのですが、このとっておきのカクテル...
# 8   （2019/12/28 再訪）約1年振り。注文したのは以下の通り。【ドリンク】 ・Maker...
# 9   私が東京で最も好きなバーでして、神楽坂にあるしっとりとしたバーです。この日は、友人たちと神楽...
# 10  この日やって来ましたのは神楽坂にあるBar『サンルーカルバー』です。都内に数あるBarの中で...
# 11  ２０１８年１２月この日は神楽坂へ。『龍朋』さんでの夕食の後、東京メトロの神楽坂駅の１番出口近...
# 12  長年恋焦がれていたサンルーカルバーについに入れたぞ♪(ﾟ∀ﾟ；)　数年前に覗いた時には満席で...
# 13  まだ明るい陽射しが。このなんとなく開放感。リゾートホテルのバー。でもないのに。店内の造りはオ...
# 14  神楽坂飲みの仕上げはこちら「サンルーカルバー」へ(^-^)/お店はバーなのに開店時間が14:...
# 15  今年の夏は、とっても暑い。暑いと喉が渇く。 ・・・ってことで、土曜日の昼下がり。14時～OP...
# 16  神楽坂下の中華料理店で中国人写真家を激励する宴の後、流れ解散で元同僚とやって来たのがこちらの...
# 17  神楽坂の有名なオーセンティックバーといえば、歯車、サンルーカルバーがやはり有名。こちらは神楽...
# 18  神楽坂上の大好きなバー．といいながら，ここしばらくお邪魔する機会がなかった．前の訪問から1年...
# 19  風情ある石畳が印象的な神楽坂に店を構える「サンルーカルバー （Sanlucar BAR）」さ...
# 20  Y&M KislingのMは毛利さんのM。旧毛利バーが閉まると聞いたときは寂しく泣いちゃいま...
# 21  ４月より移転していたニュースはネットで確認していたが、場所が変わってからの初訪問。とは言って...
# 22  【食べログ 2020 TOP 1000】【食べログ 東京×バー 第2位】(投稿時)銀座7丁目...
# 23  2004年5月某日。“また吉田氏のマティーニに悩まされる”枝川公一氏の一言が添えられた赤い葉...
# 24  マティーニの名手と呼ばれた吉田さんのマティーニを味わうことが出来なくなって心残りでしたが、銀...
# 25  銀座にはいくつか巨匠の店と言われるオーセンティックなバーがあるが、先日、そのひとつをたまたま...
# 26  ハイブランドの店が立ち並ぶ銀座に店を構える「MORI BAR」さんに伺いました。2004年5...
# 27  ワイ アンド エム バー・キスリングさんに夕食前に立ち寄りました。地下鉄 銀座駅より徒歩6分...
# 28  本日は銀座居酒屋一人旅。「ワイアンドエムバー・キスリング」へまずは行きましょうか。しばらくお...
# 29  庶民なので銀座は一度とある有名バーで怖い思いをしてから避けておりましたが、こちらと保志さんは...
# 30  Instagram (bottan222) ーーーーーーーーーーーーー2017/01　「レン...
# 31  Y＆MのMは「モーリバー」の毛利氏のMです。そしてお店にはキスリングの絵が飾られています。オ...
# 32  ★の数ほどＢＡＲのある街､｢銀座｣(オーバー)｡その｢銀座｣で名店と言われているお店も数多く...
# 33  ２０１６・６・１５②銀座の老舗大衆居酒屋でまったり飲んだのち～「ワイアンドエムバーキスリング...
# 34                           http://amzn.asia/1qozRiO
# 35  うどんが主食instagram　うどんが主食Twitterうどんが主食Facebook【再訪...
# 36  2016-4訪問銀座にあるバーにお邪魔しました。当日、食事をした後にあまり口コミ等を確認せず...
# 37  初めて伺ってから、もう5年ほど経つでしょうか。バーコートをお召しのやや年配のバーテンダーさん...
# 38  食事を済ませてテクテクと７丁目まで移動をしてまいりました。〆はバーで。良い立地にありますよ。...
# 39  資生堂本社近くのビルの7階にあるバー、ワイアンドエムバー・キスリング。店内は重厚感あります。...
# 40  言わずと知れた渋谷を代表するオーセンティックバー。オーナーバーテンダーである石垣忍さんは、世...
# 41  Instagram(bottan222)ーーーーーーーーーーーーー2020/06　６月１日の...
# 42  ＊＊短評＊＊界隈で知らぬ者はいないオーナーバーテンダー石垣氏のお店。日本を代表するバーのひと...
# 43  先輩につれられて訪れた石の華さん。店内はクラシカルでどこかモダンな雰囲気。落ち着く。まずはモ...
# 44  本日二軒目は渋谷のＢＡＲ石ノ華。平日金曜日に友人Wとの飲みにて利用。以前から友人Wの話を聞い...
# 45  本日は渋谷でお仕事。遅くなってしまったのでスポーツジムは間に合いませんね。では、大好きなバー...
# 46  東京都は渋谷区、友人との待ち合わせまで少々時間がありましたので、「！」閃きました。そうだ、バ...
# 47  何年も前に、確か京都の日航ホテルのバーで聞いたお店。やっと行ってきた。始まりはいつも通りのジ...
# 48  2018/2/16の夕食の後のバータイム本文　大学学教授の医師に結構肝臓の値が悪いので内科医...
# 49  渋谷駅の最寄りに店を構える「石の華」さんに伺いました。アクセスは、JR山手線渋谷駅より徒歩3...
# 50  渋谷。東急南口交差点から西に進んだビルの地下１階にあるバー。数々のカクテルコンクールで受賞暦...
# 51  オープンして10分程経ってからの来店。カウンター席は殆ど埋まっており、自分の来店後も次々に来...
# 52  渋谷のビル地下1階にあるバー。休日のディナーで訪問。常に満席でひっきりなしに客が来るため、事...
# 53  大衆居酒屋で鯨飲馬食。こんな日も悪くはないが、私は元来、酒には最高の質と最高の量を求めてしま...
# 54  何軒かハシゴをして渋谷にたどり着いた土曜日、終電までもう1杯ということで、こちらのバーに行っ...
# 55  2003年オープン、渋谷駅から5分程。六本木通り沿いという分かりやすい所にある世界大会で東洋...
# 56  【このお店のステキな気遣いを経験したので、再投稿をします】今日、私の家に宅急便が届きました。...
# 57  さて、石の華さんです。 こちらはバー好きなら一度は経験したい超有名店です。オーナーバーテンダ...
# 58  渋谷駅から徒歩３分の好立地。半地下に階段を降りたところにあります。ご縁があってディナーをご一...
# 59  渋谷にあるBar「石の華」はいつか行ってみたいと思っていたバーのひとつ。バー研究するならあそ...

# %%
from IPython.display import display
import pandas as pd

df = pd.read_csv('/Users/minej/anaconda3/minejis/data_summary.csv')
display(df.head())
display(df.tail())
# Out:
#    00001   サンルーカルバー    神楽坂駅 86m / バー   評価：4.02   口コミ：159件
# 0      2   MORI BAR    銀座駅 300m / バー   評価：3.92    口コミ：67件
# 1      3        石の華    渋谷駅 325m / バー   評価：3.91   口コミ：155件
# 2      4     BAR 保志    銀座駅 280m / バー   評価：3.88   口コミ：164件
# 3      5         歯車   飯田橋駅 446m / バー   評価：3.86   口コミ：129件
# 4      6       BAR五   恵比寿駅 208m / バー   評価：3.86    口コミ：44件
#     00001   サンルーカルバー   神楽坂駅 86m / バー   評価：4.02   口コミ：159件
# 14      2   MORI BAR   銀座駅 300m / バー   評価：3.92    口コミ：67件
# 15      3        石の華   渋谷駅 325m / バー   評価：3.91   口コミ：155件
# 16      1   サンルーカルバー   神楽坂駅 86m / バー   評価：4.02   口コミ：159件
# 17      2   MORI BAR   銀座駅 300m / バー   評価：3.92    口コミ：67件
# 18      3        石の華   渋谷駅 325m / バー   評価：3.91   口コミ：155件

# %%
# coding: utf-8
# 三宮　鉄板焼き
from bs4 import BeautifulSoup
import os
import re
import requests
import pandas as pd
import time

class TabelogScraping:
    """
    食べログから店名、ジャンル、評価点、口コミ件数、最新20件の口コミを取得する
    """
    def __init__(self, max_num):
        """
        インスタンス化した時点でスクレイピングを開始する
        食べログ（検索条件：東京都、バー、ランキング順）にアクセスする
        取得するページ件数は1ページ目からmax_numページ目までとする。
        """
        # スクレイピング対象となるお店のタグ    # カスタマイズ #
        self.TAGS = {'鉄板焼き', 'ステーキ', 'シーフード', 'ワインバー'}
        # スクレイピング対象となる評価点の下限値    # カスタマイズ #
        self.LOWER_LIMIT = 3.0
        # 口コミのURLへの不足部分
        self.RVW = 'dtlrvwlst/'
        # 取得したデータ一覧の保存場所 C:\Users\minej\anaconda3\minejis    # カスタマイズ #
        self.RESULT_PATH = '/Users/minej/anaconda3/minejis'
        # 取得したデータ一覧名
        self.RESULT_NAME = 'data_summary.csv'
        # 取得した口コミデータフレームの列名
        self.COLUMNS = ['store_id', 'store_name', 'genre', 'rate', 'review_cnt', 'review']
        # 検索するページ上限数
        self.max_num = max_num + 1
        self.shop_id = ''
        self.id_num = 1
        self.df = pd.DataFrame(columns = self.COLUMNS)

        try:
            first_time = time.time()
            for page_num in range(1, self.max_num):
                if page_num == 1:
                    # ランキング1ページ目    # カスタマイズ #
                    response = self.connect_url('https://tabelog.com/hyogo/A2801/A280101/R4486/rstLst/RC0203/?LstRange=SG&select_sort_flg=1')
                else:
                    # ランキング2ページ目以降    # カスタマイズ #
                    response = self.connect_url('https://tabelog.com/hyogo/A2801/A280101/R4486/rstLst/RC0203/' + str(page_num) + '/?LstRange=SG&select_sort_flg=1')

                # HTML解析用の変数
                soup = BeautifulSoup(response.text, 'lxml')

                # 一覧ページから以下の情報を取得する
                # ジャンルの取得
                genre_info = [genre.text.rstrip() for genre in soup.find_all('div', class_='list-rst__area-genre cpy-area-genre')]
                # 評価点の取得
                rate_list = [float(rate.text) for rate in soup.find_all('span', class_='c-rating__val c-rating__val--strong list-rst__rating-val')]
                # 口コミ件数の取得
                count_list = [count.text for count in soup.find_all('em', class_='list-rst__rvw-count-num cpy-review-count')]
                # 店名の取得
                raw_data = soup.find_all('a', class_='list-rst__rst-name-target cpy-rst-name js-ranking-num')
                shop_list = [name.text for name in raw_data]
                shop_url_list = [shop_url.get('href') for shop_url in raw_data]

                for i in range(20):
                    genre_tags = set(re.split('[\\s/、]+', genre_info[i].strip())[2:])
                    # ジャンル文字列が「バー、ワインバー、バー・お酒（その他）、ラウンジ、カフェ、ダイニングバー」の部分集合の場合、
                    # かつ評価点が「3.０以上」の場合、かつ、口コミ件数が１件以上存在する場合に処理を続ける
                    if not (genre_tags.issubset(self.TAGS) and rate_list[i] >= self.LOWER_LIMIT and int(count_list[i]) > 0):
                        continue

                    start_time = time.time()
                    self.shop_id = str(self.id_num).zfill(5)

                    # お店のURLに遷移し、口コミを20件(1ページ分)取得する
                    response = self.connect_url(shop_url_list[i] + self.RVW)
                    soup = BeautifulSoup(response.text, 'lxml')
                    review_url_list = soup.find_all('div', class_='rvw-item js-rvw-item-clickable-area')

                    # 各口コミページに遷移し、最新の口コミを取得する
                    for url in review_url_list:
                        review_detail_url = 'https://tabelog.com' + url.get('data-detail-url')
                        response = self.connect_url(review_detail_url)
                        soup = BeautifulSoup(response.text, 'lxml')
                        review = soup.find_all('div', class_='rvw-item__rvw-comment')
                        review = review[0].p.text.strip()
                        # pandasのデータフレームに格納
                        self.add_df(shop_list[i], genre_info[i].strip(), rate_list[i], count_list[i], review)

                    # 1つのお店のスクレイピングが終了したら、その結果を保存する
                    self.write_result(shop_list[i], genre_info[i].strip(), rate_list[i], count_list[i])

                    process_time = time.time() - start_time
                    print('{}件目完了：　処理時間：{:.3f}秒'.format(self.id_num, process_time))

                    self.id_num += 1

        except requests.exceptions.HTTPError as e:
            print(e)
        except requests.exceptions.ConnectTimeout as e:
            print(e)
        finally:
            end_time = time.time() - first_time
            print('終了、処理時間：{:.3f}秒'.format(end_time))


    def connect_url(self, target_url):
        """
        対象のURLにアクセスする関数
        アクセスできない等のエラーが発生したら例外を投げる
        """
        # 接続確立の待機時間、応答待機時間を10秒とし、それぞれの値を超えた場合は例外が発生（ConnectTimeout）
        data = requests.get(target_url, timeout=10)
        data.encoding = data.apparent_encoding
        # アクセス過多を避けるため、2秒スリープ
        time.sleep(2)

        # レスポンスのステータスコードが正常(200番台)以外の場合は、例外を発生させる(HTTPError)
        if data.status_code == requests.codes.ok:
            return data
        else:
            data.raise_for_status()


    def write_result(self, name, genre, rate, count):
        """
        スクレイピング対象となるお店の一覧をログとして出力する関数
        """
        file_path = os.path.join(self.RESULT_PATH, self.RESULT_NAME)
        with open(file_path, mode='a', encoding='utf-8') as f:
            f.write('{}, {}, {}, 評価：{}, 口コミ：{}件\n'.format(self.shop_id, name, genre, rate, count))


    def add_df(self, name, genre, rate, count, comment):
        """
        取得した口コミデータをデータフレームに格納する関数
        """
        se = pd.Series([self.shop_id, name, genre, rate, count, comment], self.COLUMNS)
        self.df = self.df.append(se, self.COLUMNS)


if __name__ == '__main__':
    result = TabelogScraping(5)
    print(result.df)
# Out:
# 終了、処理時間：15.990秒
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-834a2936678f> in <module>
#     139
#     140 if __name__ == '__main__':
# --> 141     result = TabelogScraping(5)
#     142     print(result.df)
#
# <ipython-input-7-834a2936678f> in __init__(self, max_num)
#      62
#      63                 for i in range(20):
# ---> 64                     genre_tags = set(re.split('[\\s/、]+', genre_info[i].strip())[2:])
#      65                     # ジャンル文字列が「バー、ワインバー、バー・お酒（その他）、ラウンジ、カフェ、ダイニングバー」の部分集合の場合、
#      66                     # かつ評価点が「3.０以上」の場合、かつ、口コミ件数が１件以上存在する場合に処理を続ける
#
# IndexError: list index out of range

# %%
import sys

sys.path.append('/Users/minej/anaconda3/minejis')
import Tabelog

result = Tabelog.TabelogScraping(60)
result.df.to_csv('/Users/minej/anaconda3/minejis/review_dataframe.csv')
# Out:
# 終了、処理時間：16.171秒
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-18cd83d404be> in <module>
#       4 import Tabelog
#       5
# ----> 6 result = Tabelog.TabelogScraping(60)
#       7 result.df.to_csv('/Users/minej/anaconda3/minejis/review_dataframe.csv')
#
# ~\anaconda3\Tabelog.py in __init__(self, max_num)
#      62
#      63                 for i in range(20):
# ---> 64                     genre_tags = set(re.split('[\\s/、]+', genre_info[i].strip())[2:])
#      65                     # ジャンル文字列が「バー、ワインバー、バー・お酒（その他）、ラウンジ、カフェ、ダイニングバー」の部分集合の場合、
#      66                     # かつ評価点が「3.０以上」の場合、かつ、口コミ件数が１件以上存在する場合に処理を続ける
#
# IndexError: list index out of range
